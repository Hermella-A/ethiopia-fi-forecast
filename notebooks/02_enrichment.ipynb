# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import os
import warnings
warnings.filterwarnings('ignore')

# Load existing data
df = pd.read_csv('../data/raw/ethiopia_fi_unified_data.csv')
print(f"Original dataset: {len(df)} records")
df.head()
# Out:
# Original dataset: 43 records
#   record_id  record_type category  pillar               indicator  \
# 0  REC_0001  observation      NaN  ACCESS  Account Ownership Rate
# 1  REC_0002  observation      NaN  ACCESS  Account Ownership Rate
# 2  REC_0003  observation      NaN  ACCESS  Account Ownership Rate
# 3  REC_0004  observation      NaN  ACCESS  Account Ownership Rate
# 4  REC_0005  observation      NaN  ACCESS  Account Ownership Rate
#
#   indicator_code indicator_direction  value_numeric value_text  value_type  \
# 0  ACC_OWNERSHIP       higher_better           22.0        NaN  percentage
# 1  ACC_OWNERSHIP       higher_better           35.0        NaN  percentage
# 2  ACC_OWNERSHIP       higher_better           46.0        NaN  percentage
# 3  ACC_OWNERSHIP       higher_better           56.0        NaN  percentage
# 4  ACC_OWNERSHIP       higher_better           36.0        NaN  percentage
#
#    ... impact_direction impact_magnitude impact_estimate lag_months  \
# ...

# %%
new_observations = pd.DataFrame([
    {
        'record_id': 'REC_OBS_001',
        'record_type': 'observation',
        'category': None,
        'pillar': 'ACCESS',
        'indicator': 'Agent Density (per 100k adults)',
        'indicator_code': 'ACC_AGENT_DENSITY',
        'indicator_direction': 'higher_better',
        'value_numeric': 45.0,
        'value_text': None,
        'value_type': 'numeric',
        'value_definition': 'Number of mobile money agents per 100,000 adults',
        'source_name': 'IMF Financial Access Survey',
        'source_type': 'survey',
        'source_url': 'https://data.imf.org/fas',
        'observation_date': '2024-12-31',
        'confidence': 'medium',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Agent density is a key enabler for digital payment usage',
        'original_text': 'Agent density estimated from GSMA and NBE data',
    },
    {
        'record_id': 'REC_OBS_002',
        'record_type': 'observation',
        'category': None,
        'pillar': 'ACCESS',
        'indicator': 'POS Terminals',
        'indicator_code': 'ACC_POS_TERMINALS',
        'indicator_direction': 'higher_better',
        'value_numeric': 12000.0,
        'value_text': None,
        'value_type': 'numeric',
        'value_definition': 'Number of POS terminals in Ethiopia',
        'source_name': 'National Bank of Ethiopia',
        'source_type': 'report',
        'source_url': 'https://nbe.gov.et',
        'observation_date': '2024-12-31',
        'confidence': 'medium',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'POS terminals enable digital payments at merchants',
        'original_text': 'POS terminal count from NBE annual report',
    },
    {
        'record_id': 'REC_OBS_003',
        'record_type': 'observation',
        'category': None,
        'pillar': 'ACCESS',
        'indicator': 'Mobile Internet Penetration',
        'indicator_code': 'ACC_MOBILE_INTERNET',
        'indicator_direction': 'higher_better',
        'value_numeric': 38.0,
        'value_text': None,
        'value_type': 'numeric',
        'value_definition': '% of population with mobile internet access',
        'source_name': 'ITU ICT Statistics',
        'source_type': 'survey',
        'source_url': 'https://www.itu.int/ict',
        'observation_date': '2024-12-31',
        'confidence': 'high',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Mobile internet is key for accessing mobile money services',
        'original_text': 'Mobile internet penetration from ITU data',
    },
    {
        'record_id': 'REC_OBS_004',
        'record_type': 'observation',
        'category': None,
        'pillar': 'ACCESS',
        'indicator': 'Digital ID Coverage',
        'indicator_code': 'ACC_DIGITAL_ID',
        'indicator_direction': 'higher_better',
        'value_numeric': 25.0,
        'value_text': None,
        'value_type': 'numeric',
        'value_definition': '% of population enrolled in Fayda digital ID',
        'source_name': 'National Bank of Ethiopia',
        'source_type': 'report',
        'source_url': 'https://nbe.gov.et',
        'observation_date': '2024-12-31',
        'confidence': 'medium',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Digital ID enables simplified KYC for account opening',
        'original_text': 'Fayda digital ID enrollment from NBE report',
    },
    {
        'record_id': 'REC_OBS_005',
        'record_type': 'observation',
        'category': None,
        'pillar': 'ACCESS',
        'indicator': 'Bank Branches per 100k Adults',
        'indicator_code': 'ACC_BANK_BRANCHES',
        'indicator_direction': 'higher_better',
        'value_numeric': 4.5,
        'value_text': None,
        'value_type': 'numeric',
        'value_definition': 'Number of bank branches per 100,000 adults',
        'source_name': 'IMF Financial Access Survey',
        'source_type': 'survey',
        'source_url': 'https://data.imf.org/fas',
        'observation_date': '2024-12-31',
        'confidence': 'medium',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Bank branch density indicates physical access to banking',
        'original_text': 'Bank branch data from IMF FAS',
    },
    {
        'record_id': 'REC_OBS_006',
        'record_type': 'observation',
        'category': None,
        'pillar': 'USAGE',
        'indicator': 'Smartphone Penetration',
        'indicator_code': 'USG_SMARTPHONE_PEN',
        'indicator_direction': 'higher_better',
        'value_numeric': 42.0,
        'value_text': None,
        'value_type': 'numeric',
        'value_definition': '% of population owning a smartphone',
        'source_name': 'GSMA Mobile Economy Report',
        'source_type': 'survey',
        'source_url': 'https://www.gsma.com/mobileeconomy',
        'observation_date': '2024-12-31',
        'confidence': 'high',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Smartphone ownership is critical for mobile money usage',
        'original_text': 'Smartphone penetration from GSMA data',
    },
    {
        'record_id': 'REC_OBS_007',
        'record_type': 'observation',
        'category': None,
        'pillar': 'USAGE',
        'indicator': 'Data Affordability',
        'indicator_code': 'USG_DATA_AFFORDABILITY',
        'indicator_direction': 'higher_better',
        'value_numeric': 3.5,
        'value_text': None,
        'value_type': 'numeric',
        'value_definition': '% of income for 1GB mobile data',
        'source_name': 'GSMA Mobile Economy Report',
        'source_type': 'survey',
        'source_url': 'https://www.gsma.com/mobileeconomy',
        'observation_date': '2024-12-31',
        'confidence': 'high',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Lower data costs enable digital payment adoption',
        'original_text': 'Data affordability from GSMA data',
    },
    {
        'record_id': 'REC_OBS_008',
        'record_type': 'observation',
        'category': None,
        'pillar': 'ACCESS',
        'indicator': '4G Coverage',
        'indicator_code': 'ACC_4G_COV',
        'indicator_direction': 'higher_better',
        'value_numeric': 65.0,
        'value_text': None,
        'value_type': 'numeric',
        'value_definition': '% of population covered by 4G network',
        'source_name': 'ITU ICT Statistics',
        'source_type': 'survey',
        'source_url': 'https://www.itu.int/ict',
        'observation_date': '2024-12-31',
        'confidence': 'medium',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': '4G coverage enables mobile money access',
        'original_text': '4G coverage from ITU data',
    },
    {
        'record_id': 'REC_OBS_009',
        'record_type': 'observation',
        'category': None,
        'pillar': 'ACCESS',
        'indicator': 'Literacy Rate',
        'indicator_code': 'ACC_LITERACY',
        'indicator_direction': 'higher_better',
        'value_numeric': 52.0,
        'value_text': None,
        'value_type': 'numeric',
        'value_definition': '% of adults literate',
        'source_name': 'World Bank',
        'source_type': 'survey',
        'source_url': 'https://data.worldbank.org',
        'observation_date': '2024-12-31',
        'confidence': 'high',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Literacy is important for using digital financial services',
        'original_text': 'Literacy rate from World Bank data',
    },
    {
        'record_id': 'REC_OBS_010',
        'record_type': 'observation',
        'category': None,
        'pillar': 'ACCESS',
        'indicator': 'Urbanization Rate',
        'indicator_code': 'ACC_URBANIZATION',
        'indicator_direction': 'higher_better',
        'value_numeric': 23.0,
        'value_text': None,
        'value_type': 'numeric',
        'value_definition': '% of population in urban areas',
        'source_name': 'World Bank',
        'source_type': 'survey',
        'source_url': 'https://data.worldbank.org',
        'observation_date': '2024-12-31',
        'confidence': 'high',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Urban areas have better access to financial services',
        'original_text': 'Urbanization rate from World Bank data',
    },
])

# Add the new observations
df_enriched = pd.concat([df, new_observations], ignore_index=True)
print(f"Added {len(new_observations)} new observations")
print(f"Enriched dataset: {len(df_enriched)} records")
# Out:
# Added 10 new observations
# Enriched dataset: 53 records

# %%
new_events = pd.DataFrame([
    {
        'record_id': 'REC_EVT_001',
        'record_type': 'event',
        'category': 'infrastructure',
        'pillar': None,
        'indicator': 'EthSwitch Launch',
        'indicator_code': None,
        'indicator_direction': None,
        'value_numeric': None,
        'value_text': 'National switch enabling interoperability',
        'value_type': None,
        'value_definition': None,
        'source_name': 'National Bank of Ethiopia',
        'source_type': 'news',
        'source_url': 'https://nbe.gov.et',
        'observation_date': '2020-01-01',
        'confidence': 'high',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'EthSwitch enables interoperability between banks and mobile money',
        'original_text': 'EthSwitch launched to enable interoperability',
    },
    {
        'record_id': 'REC_EVT_002',
        'record_type': 'event',
        'category': 'product_launch',
        'pillar': None,
        'indicator': 'Fayda Digital ID Rollout',
        'indicator_code': None,
        'indicator_direction': None,
        'value_numeric': None,
        'value_text': 'National digital ID system for KYC',
        'value_type': None,
        'value_definition': None,
        'source_name': 'National Bank of Ethiopia',
        'source_type': 'news',
        'source_url': 'https://nbe.gov.et',
        'observation_date': '2023-01-15',
        'confidence': 'high',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Fayda enables simplified KYC for account opening',
        'original_text': 'Fayda digital ID system rolled out',
    },
    {
        'record_id': 'REC_EVT_003',
        'record_type': 'event',
        'category': 'infrastructure',
        'pillar': None,
        'indicator': 'M-Pesa-MTN Interoperability',
        'indicator_code': None,
        'indicator_direction': None,
        'value_numeric': None,
        'value_text': 'Interoperability between M-Pesa and MTN',
        'value_type': None,
        'value_definition': None,
        'source_name': 'M-Pesa Ethiopia',
        'source_type': 'news',
        'source_url': 'https://mpesa.et',
        'observation_date': '2024-03-15',
        'confidence': 'high',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Interoperability enables seamless P2P transfers',
        'original_text': 'M-Pesa and MTN announced interoperability',
    },
    {
        'record_id': 'REC_EVT_004',
        'record_type': 'event',
        'category': 'policy',
        'pillar': None,
        'indicator': 'Mobile Money Regulatory Framework',
        'indicator_code': None,
        'indicator_direction': None,
        'value_numeric': None,
        'value_text': 'New regulatory framework for mobile money',
        'value_type': None,
        'value_definition': None,
        'source_name': 'National Bank of Ethiopia',
        'source_type': 'policy',
        'source_url': 'https://nbe.gov.et',
        'observation_date': '2024-06-01',
        'confidence': 'high',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Regulatory framework enables competition and innovation',
        'original_text': 'New mobile money regulatory framework announced',
    },
    {
        'record_id': 'REC_EVT_005',
        'record_type': 'event',
        'category': 'infrastructure',
        'pillar': None,
        'indicator': 'Mobile Money Agent Network Expansion',
        'indicator_code': None,
        'indicator_direction': None,
        'value_numeric': None,
        'value_text': 'Major expansion of agent network',
        'value_type': None,
        'value_definition': None,
        'source_name': 'GSMA Mobile Economy Report',
        'source_type': 'report',
        'source_url': 'https://www.gsma.com/mobileeconomy',
        'observation_date': '2022-06-01',
        'confidence': 'medium',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Agent network expansion drives adoption',
        'original_text': 'Mobile money agent network expanded significantly',
    },
])

# Add new events
df_enriched = pd.concat([df_enriched, new_events], ignore_index=True)
print(f"Added {len(new_events)} new events")
print(f"Enriched dataset: {len(df_enriched)} records")
# Out:
# Added 5 new events
# Enriched dataset: 58 records

# %%
new_impact_links = pd.DataFrame([
    {
        'record_id': 'REC_LINK_001',
        'record_type': 'impact_link',
        'category': None,
        'pillar': 'ACCESS',
        'indicator': None,
        'indicator_code': 'ACC_OWNERSHIP',
        'indicator_direction': 'higher_better',
        'value_numeric': None,
        'value_text': None,
        'value_type': None,
        'value_definition': None,
        'source_name': None,
        'source_type': None,
        'source_url': None,
        'observation_date': '2023-01-15',
        'confidence': 'medium',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Fayda enables simplified KYC for account opening',
        'original_text': 'Kenya\'s digital ID (Huduma Namba) boosted account ownership',
        'parent_id': 'REC_EVT_002',
        'related_indicator': 'ACC_OWNERSHIP',
        'impact_direction': 'positive',
        'impact_magnitude': 5.0,
        'impact_estimate': '+5 percentage points',
        'lag_months': 18,
        'evidence_basis': 'Kenya digital ID experience',
        'comparable_country': 'Kenya',
    },
    {
        'record_id': 'REC_LINK_002',
        'record_type': 'impact_link',
        'category': None,
        'pillar': 'USAGE',
        'indicator': None,
        'indicator_code': 'USG_P2P_COUNT',
        'indicator_direction': 'higher_better',
        'value_numeric': None,
        'value_text': None,
        'value_type': None,
        'value_definition': None,
        'source_name': None,
        'source_type': None,
        'source_url': None,
        'observation_date': '2020-01-01',
        'confidence': 'medium',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'EthSwitch enables interoperability between banks and mobile money',
        'original_text': 'Interoperability boosts P2P transfers in Kenya',
        'parent_id': 'REC_EVT_001',
        'related_indicator': 'USG_P2P_COUNT',
        'impact_direction': 'positive',
        'impact_magnitude': 10.0,
        'impact_estimate': '+10 percentage points',
        'lag_months': 12,
        'evidence_basis': 'Interoperability experience in Kenya and Tanzania',
        'comparable_country': 'Kenya',
    },
    {
        'record_id': 'REC_LINK_003',
        'record_type': 'impact_link',
        'category': None,
        'pillar': 'USAGE',
        'indicator': None,
        'indicator_code': 'USG_TELEBIRR_USERS',
        'indicator_direction': 'higher_better',
        'value_numeric': None,
        'value_text': None,
        'value_type': None,
        'value_definition': None,
        'source_name': None,
        'source_type': None,
        'source_url': None,
        'observation_date': '2024-03-15',
        'confidence': 'medium',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Interoperability increases mobile money users',
        'original_text': 'Interoperability drives mobile money adoption',
        'parent_id': 'REC_EVT_003',
        'related_indicator': 'USG_TELEBIRR_USERS',
        'impact_direction': 'positive',
        'impact_magnitude': 8.0,
        'impact_estimate': '+8 percentage points',
        'lag_months': 6,
        'evidence_basis': 'Interoperability impact on mobile money',
        'comparable_country': 'Kenya',
    },
    {
        'record_id': 'REC_LINK_004',
        'record_type': 'impact_link',
        'category': None,
        'pillar': 'ACCESS',
        'indicator': None,
        'indicator_code': 'ACC_MM_ACCOUNT',
        'indicator_direction': 'higher_better',
        'value_numeric': None,
        'value_text': None,
        'value_type': None,
        'value_definition': None,
        'source_name': None,
        'source_type': None,
        'source_url': None,
        'observation_date': '2022-06-01',
        'confidence': 'medium',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Agent expansion drives mobile money account ownership',
        'original_text': 'Agent network expansion drives adoption',
        'parent_id': 'REC_EVT_005',
        'related_indicator': 'ACC_MM_ACCOUNT',
        'impact_direction': 'positive',
        'impact_magnitude': 8.0,
        'impact_estimate': '+8 percentage points',
        'lag_months': 24,
        'evidence_basis': 'Agent density drives adoption',
        'comparable_country': 'Kenya',
    },
    {
        'record_id': 'REC_LINK_005',
        'record_type': 'impact_link',
        'category': None,
        'pillar': 'USAGE',
        'indicator': None,
        'indicator_code': 'USG_ACTIVE_RATE',
        'indicator_direction': 'higher_better',
        'value_numeric': None,
        'value_text': None,
        'value_type': None,
        'value_definition': None,
        'source_name': None,
        'source_type': None,
        'source_url': None,
        'observation_date': '2024-06-01',
        'confidence': 'medium',
        'collected_by': 'Your_Name',
        'collection_date': '2026-07-21',
        'notes': 'Regulatory framework enables innovation',
        'original_text': 'Regulatory clarity boosts active usage',
        'parent_id': 'REC_EVT_004',
        'related_indicator': 'USG_ACTIVE_RATE',
        'impact_direction': 'positive',
        'impact_magnitude': 5.0,
        'impact_estimate': '+5 percentage points',
        'lag_months': 12,
        'evidence_basis': 'Regulatory framework impact on active usage',
        'comparable_country': 'Rwanda',
    },
])

# Add new impact links
df_enriched = pd.concat([df_enriched, new_impact_links], ignore_index=True)
print(f"Added {len(new_impact_links)} new impact links")
print(f"Enriched dataset: {len(df_enriched)} records")
# Out:
# Added 5 new impact links
# Enriched dataset: 63 records

# %%
os.makedirs('../data/processed', exist_ok=True)

# Save to CSV
df_enriched.to_csv('../data/processed/ethiopia_fi_enriched.csv', index=False)
print("\n✅ Enriched dataset saved to: data/processed/ethiopia_fi_enriched.csv")
# Out:
# ✅ Enriched dataset saved to: data/processed/ethiopia_fi_enriched.csv

# %%
print("\n" + "="*60)
print("ENRICHMENT SUMMARY")
print("="*60)

print(f"\nTotal records in enriched dataset: {len(df_enriched)}")

print(f"\nRecord types:")
print(df_enriched['record_type'].value_counts())

print(f"\nNew Observations added: {len(new_observations)}")
print(f"New Events added: {len(new_events)}")
print(f"New Impact Links added: {len(new_impact_links)}")

print("\nIndicators in enriched dataset:")
print(df_enriched[df_enriched['record_type'] == 'observation']['indicator_code'].nunique())
print(df_enriched[df_enriched['record_type'] == 'observation']['indicator_code'].unique())

print("\n✅ Enrichment complete! Now run Task 2: Event Impact Analysis.")
# Out:
# ...
# ENRICHMENT SUMMARY
# ...
#
# Total records in enriched dataset: 63
#
# Record types:
# record_type
# observation    40
# event          15
# impact_link     5
# target          3
# Name: count, dtype: int64
#
# New Observations added: 10
# New Events added: 5
# New Impact Links added: 5
#
# Indicators in enriched dataset:
# 28
# ['ACC_OWNERSHIP' 'ACC_MM_ACCOUNT' 'ACC_4G_COV' 'ACC_MOBILE_PEN'
#  'ACC_FAYDA' 'USG_P2P_COUNT' 'USG_P2P_VALUE' 'USG_ATM_COUNT'
#  'USG_ATM_VALUE' 'USG_CROSSOVER' 'USG_TELEBIRR_USERS' 'USG_TELEBIRR_VALUE'
#  'USG_MPESA_USERS' 'USG_MPESA_ACTIVE' 'USG_ACTIVE_RATE' 'AFF_DATA_INCOME'
#  'GEN_GAP_ACC' 'GEN_MM_SHARE' 'GEN_GAP_MOBILE' 'ACC_AGENT_DENSITY'
#  'ACC_POS_TERMINALS' 'ACC_MOBILE_INTERNET' 'ACC_DIGITAL_ID'
#  'ACC_BANK_BRANCHES' 'USG_SMARTPHONE_PEN' 'USG_DATA_AFFORDABILITY'
#  'ACC_LITERACY' 'ACC_URBANIZATION']
#
# ✅ Enrichment complete! Now run Task 2: Event Impact Analysis.
